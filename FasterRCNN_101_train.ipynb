# %% [markdown]
# <h3>Package Installations</h3>

# %%
# %%shell
#
# pip install cython
# # Install pycocotools, the version by default in Colab
# # has a bug fixed in https://github.com/cocodataset/cocoapi/pull/354
# pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# Out:
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (0.29.21)
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-_k9380ip
#   Running command git clone -q https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-_k9380ip
# Requirement already satisfied, skipping upgrade: setuptools>=18.0 in /usr/local/lib/python3.6/dist-packages (from pycocotools==2.0) (49.2.0)
# Requirement already satisfied, skipping upgrade: cython>=0.27.3 in /usr/local/lib/python3.6/dist-packages (from pycocotools==2.0) (0.29.21)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from pycocotools==2.0) (3.2.2)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.2.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.11 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.18.5)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.4.7)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from cycler>=0.10->matplotlib>=2.1.0->pycocotools==2.0) (1.15.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp36-cp36m-linux_x86_64.whl size=266457 sha256=1dc8187d5a248eb090b7e62add8e38ad4e65f4a3178cd15be042dfbf3d6f62f1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vakxftq4/wheels/90/51/41/646daf401c3bc408ff10de34ec76587a9b3ebfac8d21ca5c3a
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Found existing installation: pycocotools 2.0
#     Uninstalling pycocotools-2.0:
#       Successfully uninstalled pycocotools-2.0
# Successfully installed pycocotools-2.0

# %% [markdown]
# <h3>Dataloading and Dataset preparation</h3>

# %%
import pandas as pd
import ast

ANNOTATION_FILEPATH = '/content/drive/My Drive/wheat_detection/data/'
TRAIN_FILEPATH = ANNOTATION_FILEPATH+'train_split.csv'
VAL_FILEPATH = ANNOTATION_FILEPATH+'val_split.csv'
train_split_df = pd.read_csv(TRAIN_FILEPATH)
val_split_df = pd.read_csv(VAL_FILEPATH)
train_split_df['bbox'] = train_split_df['bbox'].apply(ast.literal_eval)
val_split_df['bbox'] = val_split_df['bbox'].apply(ast.literal_eval)

print(train_split_df.shape)
print(val_split_df.shape)
# Out:
# (3005, 2)
# (368, 2)

# %%
import os
import torch
from PIL import Image

class WheatDataset(torch.utils.data.Dataset):
    def __init__(self, root, image_ids, bboxes, transforms=None):
        self.root = root
        self.image_ids = image_ids
        self.bboxes = bboxes
        self.transforms = transforms
    
    def __getitem__(self, index):
        img_path = os.path.join(self.root, self.image_ids[index]+'.jpg')
        img = Image.open(img_path).convert("RGB")
        boxes = self.bboxes[index]
        # there is only one class
        labels = torch.ones((len(boxes),), dtype=torch.int64)
        # suppose all instances are not crowd
        iscrowd = torch.zeros((len(boxes),), dtype=torch.int64)
        
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        
        image_id = torch.tensor([index])
        
        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target
    
    def __len__(self):
        return len(self.image_ids)

# %%
# %%shell
#
# # Download TorchVision repo to use some files from
# # references/detection
# git clone https://github.com/pytorch/vision.git
# cd vision
# git checkout v0.6.1
#
# cp references/detection/utils.py ../
# cp references/detection/transforms.py ../
# cp references/detection/coco_eval.py ../
# cp references/detection/engine.py ../
# cp references/detection/coco_utils.py ../
# Out:
# fatal: destination path 'vision' already exists and is not an empty directory.
# HEAD is now at fe36f06 .circleci: Regenerate configs

# %%
import transforms as T
import utils

def get_transform(train):
    transforms = []
    # converts the image, a PIL image, into a PyTorch Tensor
    transforms.append(T.ToTensor())
    if train:
        # during training, randomly flip the training images
        # and ground-truth for data augmentation
        transforms.append(T.RandomHorizontalFlip(0.5))
    return T.Compose(transforms)

# %%
DATA_ROOT='/content/drive/My Drive/wheat_detection/data/train'

train_image_ids = train_split_df['image_id'].to_list()
train_bboxes = train_split_df['bbox'].to_list()

val_image_ids = val_split_df['image_id'].to_list()
val_bboxes = val_split_df['bbox'].to_list()

#create datasets
train_dataset = WheatDataset(DATA_ROOT, train_image_ids, train_bboxes, get_transform(train=True))
val_dataset =  WheatDataset(DATA_ROOT, val_image_ids, val_bboxes, get_transform(train=False))



# define training and validation data loaders
train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=4, shuffle=True, num_workers=4,
    collate_fn=utils.collate_fn)

val_loader = torch.utils.data.DataLoader(
    val_dataset, batch_size=4, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)

# %% [markdown]
# <h3>Define model and start training</h3>

# %%
import torch
import torchvision
from torchvision.models.detection.backbone_utils import resnet_fpn_backbone
from torchvision.models.detection import FasterRCNN

def fasterrcnn_101_fpn(num_classes, pretrained_backbone=True, trainable_backbone_layers=3, **kwargs):
    backbone_fpn = resnet_fpn_backbone(backbone_name='resnet101', pretrained=pretrained_backbone, trainable_layers=trainable_backbone_layers)
    model = FasterRCNN(backbone_fpn, num_classes=num_classes, **kwargs)
    return model

# %%
PRETRAINED_MODEL_PATH = '/content/drive/My Drive/wheat_detection/checkpoints/faster_rcnn_resnet101/exp1/faster_rcnn_101_fpn_epoch15.pth'

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

NUM_CLASSES = 2

#get the model using helper function
model = fasterrcnn_101_fpn(NUM_CLASSES, pretrained_backbone=False)

#load model weights
model.load_state_dict(torch.load(PRETRAINED_MODEL_PATH))

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.001, momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
#10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=8, gamma=0.1)

# %%
from engine import train_one_epoch, evaluate

MODEL_SAVE_PATH='/content/drive/My Drive/wheat_detection/checkpoints/faster_rcnn_resnet101/exp2/'


# let's train it for 20 epochs
num_epochs = 20

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, train_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, val_loader, device=device)
    torch.save(model.state_dict(), MODEL_SAVE_PATH+"faster_rcnn_101_fpn_latest.pth")
    if(epoch+1) % 5 == 0:
        torch.save(model.state_dict(), MODEL_SAVE_PATH+"faster_rcnn_101_fpn_epoch{}.pth".format(epoch+1))
# Out:
# /usr/local/lib/python3.6/dist-packages/torchvision/ops/boxes.py:101: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   keep = keep.nonzero().squeeze(1)
# Epoch: [0]  [  0/752]  eta: 0:38:40  lr: 0.000002  loss: 0.7162 (0.7162)  loss_classifier: 0.1870 (0.1870)  loss_box_reg: 0.4251 (0.4251)  loss_objectness: 0.0388 (0.0388)  loss_rpn_box_reg: 0.0652 (0.0652)  time: 3.0851  data: 1.3951  max mem: 4133
# Epoch: [0]  [ 10/752]  eta: 0:11:19  lr: 0.000016  loss: 0.6527 (0.6604)  loss_classifier: 0.1870 (0.1827)  loss_box_reg: 0.3812 (0.3906)  loss_objectness: 0.0285 (0.0291)  loss_rpn_box_reg: 0.0575 (0.0582)  time: 0.9164  data: 0.1433  max mem: 4551
# Epoch: [0]  [ 20/752]  eta: 0:09:55  lr: 0.000029  loss: 0.6527 (0.6678)  loss_classifier: 0.1876 (0.1868)  loss_box_reg: 0.3815 (0.3931)  loss_objectness: 0.0257 (0.0305)  loss_rpn_box_reg: 0.0552 (0.0574)  time: 0.6994  data: 0.0174  max mem: 4551
# Epoch: [0]  [ 30/752]  eta: 0:09:20  lr: 0.000042  loss: 0.6798 (0.6806)  loss_classifier: 0.2026 (0.1909)  loss_box_reg: 0.4088 (0.4012)  loss_objectness: 0.0269 (0.0318)  loss_rpn_box_reg: 0.0552 (0.0567)  time: 0.7003  data: 0.0163  max mem: 4551
# Epoch: [0]  [ 40/752]  eta: 0:08:59  lr: 0.000056  loss: 0.6798 (0.6830)  loss_classifier: 0.1948 (0.1913)  loss_box_reg: 0.3999 (0.4035)  loss_objectness: 0.0338 (0.0318)  loss_rpn_box_reg: 0.0534 (0.0566)  time: 0.6999  data: 0.0160  max mem: 4551
# Epoch: [0]  [ 50/752]  eta: 0:08:43  lr: 0.000069  loss: 0.6967 (0.6896)  loss_classifier: 0.1948 (0.1931)  loss_box_reg: 0.4077 (0.4062)  loss_objectness: 0.0362 (0.0329)  loss_rpn_box_reg: 0.0557 (0.0574)  time: 0.6970  data: 0.0157  max mem: 4551
# Epoch: [0]  [ 60/752]  eta: 0:08:30  lr: 0.000082  loss: 0.7007 (0.6834)  loss_classifier: 0.1929 (0.1915)  loss_box_reg: 0.4048 (0.4027)  loss_objectness: 0.0348 (0.0329)  loss_rpn_box_reg: 0.0558 (0.0564)  time: 0.6964  data: 0.0167  max mem: 4551
# Epoch: [0]  [ 70/752]  eta: 0:08:19  lr: 0.000095  loss: 0.6368 (0.6848)  loss_classifier: 0.1846 (0.1922)  loss_box_reg: 0.3825 (0.4014)  loss_objectness: 0.0355 (0.0342)  loss_rpn_box_reg: 0.0541 (0.0571)  time: 0.6985  data: 0.0165  max mem: 4551
# Epoch: [0]  [ 80/752]  eta: 0:08:08  lr: 0.000109  loss: 0.6786 (0.6835)  loss_classifier: 0.1898 (0.1915)  loss_box_reg: 0.3963 (0.4011)  loss_objectness: 0.0355 (0.0339)  loss_rpn_box_reg: 0.0559 (0.0570)  time: 0.6968  data: 0.0153  max mem: 4551
# Epoch: [0]  [ 90/752]  eta: 0:07:59  lr: 0.000122  loss: 0.6781 (0.6815)  loss_classifier: 0.1882 (0.1910)  loss_box_reg: 0.3963 (0.3996)  loss_objectness: 0.0289 (0.0336)  loss_rpn_box_reg: 0.0554 (0.0573)  time: 0.6972  data: 0.0155  max mem: 4551
# Epoch: [0]  [100/752]  eta: 0:07:50  lr: 0.000135  loss: 0.6383 (0.6787)  loss_classifier: 0.1734 (0.1898)  loss_box_reg: 0.3749 (0.3980)  loss_objectness: 0.0318 (0.0340)  loss_rpn_box_reg: 0.0546 (0.0569)  time: 0.6992  data: 0.0155  max mem: 4551
# Epoch: [0]  [110/752]  eta: 0:07:42  lr: 0.000149  loss: 0.6709 (0.6813)  loss_classifier: 0.1775 (0.1898)  loss_box_reg: 0.3929 (0.3989)  loss_objectness: 0.0341 (0.0352)  loss_rpn_box_reg: 0.0563 (0.0574)  time: 0.6977  data: 0.0156  max mem: 4551
# Epoch: [0]  [120/752]  eta: 0:07:33  lr: 0.000162  loss: 0.6828 (0.6797)  loss_classifier: 0.1846 (0.1893)  loss_box_reg: 0.4000 (0.3987)  loss_objectness: 0.0294 (0.0346)  loss_rpn_box_reg: 0.0563 (0.0571)  time: 0.6991  data: 0.0162  max mem: 4551
# Epoch: [0]  [130/752]  eta: 0:07:25  lr: 0.000175  loss: 0.6615 (0.6806)  loss_classifier: 0.1846 (0.1896)  loss_box_reg: 0.4012 (0.3988)  loss_objectness: 0.0293 (0.0346)  loss_rpn_box_reg: 0.0491 (0.0576)  time: 0.6978  data: 0.0164  max mem: 4551
# Epoch: [0]  [140/752]  eta: 0:07:17  lr: 0.000189  loss: 0.6523 (0.6812)  loss_classifier: 0.1861 (0.1902)  loss_box_reg: 0.4058 (0.3988)  loss_objectness: 0.0346 (0.0346)  loss_rpn_box_reg: 0.0503 (0.0576)  time: 0.6976  data: 0.0157  max mem: 4551
# Epoch: [0]  [150/752]  eta: 0:07:09  lr: 0.000202  loss: 0.7001 (0.6812)  loss_classifier: 0.1902 (0.1904)  loss_box_reg: 0.3992 (0.3985)  loss_objectness: 0.0315 (0.0342)  loss_rpn_box_reg: 0.0573 (0.0581)  time: 0.6974  data: 0.0153  max mem: 4551
# Epoch: [0]  [160/752]  eta: 0:07:01  lr: 0.000215  loss: 0.6888 (0.6811)  loss_classifier: 0.1902 (0.1899)  loss_box_reg: 0.4030 (0.3991)  loss_objectness: 0.0281 (0.0341)  loss_rpn_box_reg: 0.0577 (0.0579)  time: 0.6942  data: 0.0154  max mem: 4551
# Epoch: [0]  [170/752]  eta: 0:06:54  lr: 0.000228  loss: 0.6568 (0.6791)  loss_classifier: 0.1867 (0.1896)  loss_box_reg: 0.3983 (0.3979)  loss_objectness: 0.0267 (0.0341)  loss_rpn_box_reg: 0.0568 (0.0575)  time: 0.6949  data: 0.0154  max mem: 4551
# Epoch: [0]  [180/752]  eta: 0:06:46  lr: 0.000242  loss: 0.6278 (0.6753)  loss_classifier: 0.1841 (0.1884)  loss_box_reg: 0.3656 (0.3960)  loss_objectness: 0.0267 (0.0338)  loss_rpn_box_reg: 0.0510 (0.0571)  time: 0.6948  data: 0.0153  max mem: 4551
# Epoch: [0]  [190/752]  eta: 0:06:39  lr: 0.000255  loss: 0.6471 (0.6795)  loss_classifier: 0.1858 (0.1892)  loss_box_reg: 0.3993 (0.3975)  loss_objectness: 0.0310 (0.0350)  loss_rpn_box_reg: 0.0529 (0.0579)  time: 0.6959  data: 0.0155  max mem: 4551
# Epoch: [0]  [200/752]  eta: 0:06:31  lr: 0.000268  loss: 0.7206 (0.6803)  loss_classifier: 0.1900 (0.1893)  loss_box_reg: 0.4094 (0.3979)  loss_objectness: 0.0371 (0.0348)  loss_rpn_box_reg: 0.0644 (0.0582)  time: 0.6996  data: 0.0163  max mem: 4551
# Epoch: [0]  [210/752]  eta: 0:06:24  lr: 0.000282  loss: 0.6566 (0.6801)  loss_classifier: 0.1851 (0.1893)  loss_box_reg: 0.3928 (0.3978)  loss_objectness: 0.0343 (0.0348)  loss_rpn_box_reg: 0.0569 (0.0582)  time: 0.6980  data: 0.0164  max mem: 4551
# Epoch: [0]  [220/752]  eta: 0:06:16  lr: 0.000295  loss: 0.6814 (0.6824)  loss_classifier: 0.1887 (0.1897)  loss_box_reg: 0.4046 (0.3986)  loss_objectness: 0.0346 (0.0351)  loss_rpn_box_reg: 0.0567 (0.0589)  time: 0.6956  data: 0.0158  max mem: 4551
# Epoch: [0]  [230/752]  eta: 0:06:09  lr: 0.000308  loss: 0.6893 (0.6816)  loss_classifier: 0.1978 (0.1897)  loss_box_reg: 0.4046 (0.3981)  loss_objectness: 0.0314 (0.0350)  loss_rpn_box_reg: 0.0526 (0.0588)  time: 0.6953  data: 0.0163  max mem: 4551
# Epoch: [0]  [240/752]  eta: 0:06:02  lr: 0.000322  loss: 0.6610 (0.6825)  loss_classifier: 0.1803 (0.1899)  loss_box_reg: 0.3834 (0.3981)  loss_objectness: 0.0297 (0.0356)  loss_rpn_box_reg: 0.0542 (0.0590)  time: 0.6985  data: 0.0174  max mem: 4551
# Epoch: [0]  [250/752]  eta: 0:05:54  lr: 0.000335  loss: 0.6422 (0.6823)  loss_classifier: 0.1803 (0.1898)  loss_box_reg: 0.3834 (0.3982)  loss_objectness: 0.0332 (0.0354)  loss_rpn_box_reg: 0.0534 (0.0590)  time: 0.6989  data: 0.0180  max mem: 4551
# Epoch: [0]  [260/752]  eta: 0:05:47  lr: 0.000348  loss: 0.6431 (0.6813)  loss_classifier: 0.1844 (0.1896)  loss_box_reg: 0.3813 (0.3980)  loss_objectness: 0.0264 (0.0351)  loss_rpn_box_reg: 0.0459 (0.0586)  time: 0.6940  data: 0.0166  max mem: 4551
# Epoch: [0]  [270/752]  eta: 0:05:40  lr: 0.000361  loss: 0.6505 (0.6816)  loss_classifier: 0.1790 (0.1896)  loss_box_reg: 0.3836 (0.3980)  loss_objectness: 0.0264 (0.0352)  loss_rpn_box_reg: 0.0561 (0.0587)  time: 0.6968  data: 0.0159  max mem: 4551
# Epoch: [0]  [280/752]  eta: 0:05:33  lr: 0.000375  loss: 0.6505 (0.6801)  loss_classifier: 0.1772 (0.1891)  loss_box_reg: 0.3964 (0.3976)  loss_objectness: 0.0293 (0.0350)  loss_rpn_box_reg: 0.0569 (0.0585)  time: 0.7012  data: 0.0167  max mem: 4551
# Epoch: [0]  [290/752]  eta: 0:05:26  lr: 0.000388  loss: 0.6873 (0.6819)  loss_classifier: 0.1842 (0.1894)  loss_box_reg: 0.4028 (0.3985)  loss_objectness: 0.0293 (0.0351)  loss_rpn_box_reg: 0.0569 (0.0589)  time: 0.6998  data: 0.0162  max mem: 4551
# Epoch: [0]  [300/752]  eta: 0:05:18  lr: 0.000401  loss: 0.6887 (0.6824)  loss_classifier: 0.1891 (0.1895)  loss_box_reg: 0.4080 (0.3987)  loss_objectness: 0.0296 (0.0350)  loss_rpn_box_reg: 0.0580 (0.0592)  time: 0.6958  data: 0.0153  max mem: 4551
# Epoch: [0]  [310/752]  eta: 0:05:11  lr: 0.000415  loss: 0.7164 (0.6838)  loss_classifier: 0.1943 (0.1900)  loss_box_reg: 0.4152 (0.3995)  loss_objectness: 0.0296 (0.0349)  loss_rpn_box_reg: 0.0603 (0.0593)  time: 0.6956  data: 0.0155  max mem: 4551
# Epoch: [0]  [320/752]  eta: 0:05:04  lr: 0.000428  loss: 0.7164 (0.6843)  loss_classifier: 0.1945 (0.1902)  loss_box_reg: 0.4152 (0.3997)  loss_objectness: 0.0306 (0.0352)  loss_rpn_box_reg: 0.0603 (0.0593)  time: 0.6956  data: 0.0155  max mem: 4551
# Epoch: [0]  [330/752]  eta: 0:04:57  lr: 0.000441  loss: 0.7048 (0.6853)  loss_classifier: 0.1941 (0.1906)  loss_box_reg: 0.4005 (0.3999)  loss_objectness: 0.0394 (0.0354)  loss_rpn_box_reg: 0.0554 (0.0594)  time: 0.6940  data: 0.0153  max mem: 4551
# Epoch: [0]  [340/752]  eta: 0:04:50  lr: 0.000455  loss: 0.7048 (0.6859)  loss_classifier: 0.1882 (0.1907)  loss_box_reg: 0.4056 (0.4002)  loss_objectness: 0.0442 (0.0356)  loss_rpn_box_reg: 0.0553 (0.0595)  time: 0.6958  data: 0.0159  max mem: 4551
# Epoch: [0]  [350/752]  eta: 0:04:43  lr: 0.000468  loss: 0.6742 (0.6849)  loss_classifier: 0.1837 (0.1902)  loss_box_reg: 0.3969 (0.3998)  loss_objectness: 0.0339 (0.0355)  loss_rpn_box_reg: 0.0539 (0.0593)  time: 0.6971  data: 0.0161  max mem: 4551
# Epoch: [0]  [360/752]  eta: 0:04:35  lr: 0.000481  loss: 0.6585 (0.6845)  loss_classifier: 0.1859 (0.1902)  loss_box_reg: 0.3865 (0.3996)  loss_objectness: 0.0274 (0.0354)  loss_rpn_box_reg: 0.0541 (0.0592)  time: 0.6959  data: 0.0156  max mem: 4551
# Epoch: [0]  [370/752]  eta: 0:04:28  lr: 0.000495  loss: 0.6585 (0.6846)  loss_classifier: 0.1868 (0.1902)  loss_box_reg: 0.3865 (0.3997)  loss_objectness: 0.0274 (0.0354)  loss_rpn_box_reg: 0.0580 (0.0593)  time: 0.6955  data: 0.0155  max mem: 4551
# Epoch: [0]  [380/752]  eta: 0:04:21  lr: 0.000508  loss: 0.6629 (0.6838)  loss_classifier: 0.1844 (0.1900)  loss_box_reg: 0.4006 (0.3993)  loss_objectness: 0.0261 (0.0352)  loss_rpn_box_reg: 0.0597 (0.0592)  time: 0.6972  data: 0.0157  max mem: 4551
# Epoch: [0]  [390/752]  eta: 0:04:14  lr: 0.000521  loss: 0.6694 (0.6845)  loss_classifier: 0.1811 (0.1899)  loss_box_reg: 0.3996 (0.3993)  loss_objectness: 0.0256 (0.0356)  loss_rpn_box_reg: 0.0556 (0.0596)  time: 0.6982  data: 0.0168  max mem: 4551
# Epoch: [0]  [400/752]  eta: 0:04:07  lr: 0.000534  loss: 0.6942 (0.6855)  loss_classifier: 0.1911 (0.1902)  loss_box_reg: 0.4009 (0.3999)  loss_objectness: 0.0319 (0.0358)  loss_rpn_box_reg: 0.0579 (0.0597)  time: 0.6972  data: 0.0164  max mem: 4551
# Epoch: [0]  [410/752]  eta: 0:04:00  lr: 0.000548  loss: 0.6840 (0.6852)  loss_classifier: 0.1910 (0.1899)  loss_box_reg: 0.4074 (0.4000)  loss_objectness: 0.0329 (0.0357)  loss_rpn_box_reg: 0.0536 (0.0595)  time: 0.6959  data: 0.0154  max mem: 4551
# Epoch: [0]  [420/752]  eta: 0:03:53  lr: 0.000561  loss: 0.6779 (0.6862)  loss_classifier: 0.1815 (0.1900)  loss_box_reg: 0.3972 (0.4005)  loss_objectness: 0.0378 (0.0359)  loss_rpn_box_reg: 0.0570 (0.0597)  time: 0.6969  data: 0.0155  max mem: 4551
# Epoch: [0]  [430/752]  eta: 0:03:46  lr: 0.000574  loss: 0.7459 (0.6873)  loss_classifier: 0.2032 (0.1905)  loss_box_reg: 0.4199 (0.4008)  loss_objectness: 0.0393 (0.0361)  loss_rpn_box_reg: 0.0627 (0.0599)  time: 0.6960  data: 0.0153  max mem: 4551
# Epoch: [0]  [440/752]  eta: 0:03:39  lr: 0.000588  loss: 0.7275 (0.6873)  loss_classifier: 0.1990 (0.1905)  loss_box_reg: 0.4199 (0.4009)  loss_objectness: 0.0327 (0.0359)  loss_rpn_box_reg: 0.0627 (0.0599)  time: 0.6941  data: 0.0154  max mem: 4551
# Epoch: [0]  [450/752]  eta: 0:03:32  lr: 0.000601  loss: 0.6427 (0.6863)  loss_classifier: 0.1788 (0.1902)  loss_box_reg: 0.3821 (0.4004)  loss_objectness: 0.0284 (0.0358)  loss_rpn_box_reg: 0.0575 (0.0599)  time: 0.6965  data: 0.0158  max mem: 4551
# Epoch: [0]  [460/752]  eta: 0:03:25  lr: 0.000614  loss: 0.6423 (0.6855)  loss_classifier: 0.1754 (0.1899)  loss_box_reg: 0.3821 (0.4001)  loss_objectness: 0.0314 (0.0357)  loss_rpn_box_reg: 0.0589 (0.0599)  time: 0.6999  data: 0.0164  max mem: 4551
# Epoch: [0]  [470/752]  eta: 0:03:18  lr: 0.000628  loss: 0.6423 (0.6845)  loss_classifier: 0.1777 (0.1896)  loss_box_reg: 0.3804 (0.3997)  loss_objectness: 0.0296 (0.0355)  loss_rpn_box_reg: 0.0576 (0.0597)  time: 0.6978  data: 0.0168  max mem: 4551
# Epoch: [0]  [480/752]  eta: 0:03:10  lr: 0.000641  loss: 0.6580 (0.6852)  loss_classifier: 0.1817 (0.1897)  loss_box_reg: 0.3942 (0.4003)  loss_objectness: 0.0325 (0.0355)  loss_rpn_box_reg: 0.0572 (0.0598)  time: 0.6946  data: 0.0163  max mem: 4551
# Epoch: [0]  [490/752]  eta: 0:03:03  lr: 0.000654  loss: 0.7156 (0.6857)  loss_classifier: 0.1992 (0.1898)  loss_box_reg: 0.4134 (0.4006)  loss_objectness: 0.0335 (0.0355)  loss_rpn_box_reg: 0.0572 (0.0598)  time: 0.6960  data: 0.0158  max mem: 4551
# Epoch: [0]  [500/752]  eta: 0:02:56  lr: 0.000667  loss: 0.6819 (0.6854)  loss_classifier: 0.1824 (0.1898)  loss_box_reg: 0.4080 (0.4005)  loss_objectness: 0.0318 (0.0354)  loss_rpn_box_reg: 0.0549 (0.0597)  time: 0.6955  data: 0.0160  max mem: 4551
# Epoch: [0]  [510/752]  eta: 0:02:49  lr: 0.000681  loss: 0.6819 (0.6853)  loss_classifier: 0.1848 (0.1898)  loss_box_reg: 0.4026 (0.4004)  loss_objectness: 0.0318 (0.0354)  loss_rpn_box_reg: 0.0599 (0.0597)  time: 0.6957  data: 0.0155  max mem: 4551
# Epoch: [0]  [520/752]  eta: 0:02:42  lr: 0.000694  loss: 0.6913 (0.6870)  loss_classifier: 0.1897 (0.1898)  loss_box_reg: 0.4039 (0.4008)  loss_objectness: 0.0319 (0.0362)  loss_rpn_box_reg: 0.0605 (0.0602)  time: 0.6956  data: 0.0155  max mem: 4551
# Epoch: [0]  [530/752]  eta: 0:02:35  lr: 0.000707  loss: 0.6835 (0.6860)  loss_classifier: 0.1812 (0.1895)  loss_box_reg: 0.4026 (0.4003)  loss_objectness: 0.0319 (0.0362)  loss_rpn_box_reg: 0.0509 (0.0601)  time: 0.6961  data: 0.0157  max mem: 4551
# Epoch: [0]  [540/752]  eta: 0:02:28  lr: 0.000721  loss: 0.6555 (0.6859)  loss_classifier: 0.1741 (0.1895)  loss_box_reg: 0.3877 (0.4002)  loss_objectness: 0.0343 (0.0362)  loss_rpn_box_reg: 0.0504 (0.0599)  time: 0.6972  data: 0.0157  max mem: 4551
# Epoch: [0]  [550/752]  eta: 0:02:21  lr: 0.000734  loss: 0.6840 (0.6862)  loss_classifier: 0.1992 (0.1897)  loss_box_reg: 0.3936 (0.4004)  loss_objectness: 0.0317 (0.0362)  loss_rpn_box_reg: 0.0508 (0.0599)  time: 0.6982  data: 0.0164  max mem: 4551
# Epoch: [0]  [560/752]  eta: 0:02:14  lr: 0.000747  loss: 0.6576 (0.6853)  loss_classifier: 0.1858 (0.1895)  loss_box_reg: 0.3862 (0.3999)  loss_objectness: 0.0294 (0.0362)  loss_rpn_box_reg: 0.0536 (0.0597)  time: 0.6987  data: 0.0161  max mem: 4551
# Epoch: [0]  [570/752]  eta: 0:02:07  lr: 0.000761  loss: 0.6567 (0.6852)  loss_classifier: 0.1840 (0.1894)  loss_box_reg: 0.3850 (0.4000)  loss_objectness: 0.0285 (0.0361)  loss_rpn_box_reg: 0.0508 (0.0597)  time: 0.6950  data: 0.0155  max mem: 4551
# Epoch: [0]  [580/752]  eta: 0:02:00  lr: 0.000774  loss: 0.6494 (0.6847)  loss_classifier: 0.1930 (0.1893)  loss_box_reg: 0.3850 (0.3996)  loss_objectness: 0.0290 (0.0361)  loss_rpn_box_reg: 0.0534 (0.0597)  time: 0.6955  data: 0.0160  max mem: 4551
# Epoch: [0]  [590/752]  eta: 0:01:53  lr: 0.000787  loss: 0.6401 (0.6845)  loss_classifier: 0.1815 (0.1893)  loss_box_reg: 0.3738 (0.3993)  loss_objectness: 0.0336 (0.0362)  loss_rpn_box_reg: 0.0535 (0.0598)  time: 0.6953  data: 0.0161  max mem: 4551
# Epoch: [0]  [600/752]  eta: 0:01:46  lr: 0.000800  loss: 0.6519 (0.6840)  loss_classifier: 0.1847 (0.1891)  loss_box_reg: 0.3871 (0.3989)  loss_objectness: 0.0308 (0.0362)  loss_rpn_box_reg: 0.0537 (0.0597)  time: 0.6968  data: 0.0161  max mem: 4551
# Epoch: [0]  [610/752]  eta: 0:01:39  lr: 0.000814  loss: 0.6770 (0.6842)  loss_classifier: 0.1847 (0.1892)  loss_box_reg: 0.3953 (0.3992)  loss_objectness: 0.0282 (0.0361)  loss_rpn_box_reg: 0.0528 (0.0597)  time: 0.6990  data: 0.0164  max mem: 4551
# Epoch: [0]  [620/752]  eta: 0:01:32  lr: 0.000827  loss: 0.6765 (0.6841)  loss_classifier: 0.1816 (0.1889)  loss_box_reg: 0.3978 (0.3989)  loss_objectness: 0.0287 (0.0364)  loss_rpn_box_reg: 0.0518 (0.0599)  time: 0.6967  data: 0.0160  max mem: 4551
# Epoch: [0]  [630/752]  eta: 0:01:25  lr: 0.000840  loss: 0.6535 (0.6839)  loss_classifier: 0.1816 (0.1890)  loss_box_reg: 0.3865 (0.3988)  loss_objectness: 0.0287 (0.0363)  loss_rpn_box_reg: 0.0518 (0.0597)  time: 0.7005  data: 0.0166  max mem: 4551
# Epoch: [0]  [640/752]  eta: 0:01:18  lr: 0.000854  loss: 0.6535 (0.6838)  loss_classifier: 0.1874 (0.1891)  loss_box_reg: 0.3901 (0.3988)  loss_objectness: 0.0262 (0.0362)  loss_rpn_box_reg: 0.0551 (0.0598)  time: 0.7024  data: 0.0177  max mem: 4551
# Epoch: [0]  [650/752]  eta: 0:01:11  lr: 0.000867  loss: 0.6617 (0.6839)  loss_classifier: 0.1868 (0.1891)  loss_box_reg: 0.3878 (0.3989)  loss_objectness: 0.0261 (0.0361)  loss_rpn_box_reg: 0.0590 (0.0598)  time: 0.7015  data: 0.0171  max mem: 4551
# Epoch: [0]  [660/752]  eta: 0:01:04  lr: 0.000880  loss: 0.6617 (0.6836)  loss_classifier: 0.1845 (0.1890)  loss_box_reg: 0.3940 (0.3988)  loss_objectness: 0.0261 (0.0359)  loss_rpn_box_reg: 0.0530 (0.0598)  time: 0.7035  data: 0.0175  max mem: 4551
# Epoch: [0]  [670/752]  eta: 0:00:57  lr: 0.000894  loss: 0.6557 (0.6835)  loss_classifier: 0.1904 (0.1891)  loss_box_reg: 0.3940 (0.3988)  loss_objectness: 0.0267 (0.0358)  loss_rpn_box_reg: 0.0528 (0.0597)  time: 0.7034  data: 0.0179  max mem: 4551
# Epoch: [0]  [680/752]  eta: 0:00:50  lr: 0.000907  loss: 0.6605 (0.6833)  loss_classifier: 0.1785 (0.1890)  loss_box_reg: 0.3917 (0.3988)  loss_objectness: 0.0271 (0.0358)  loss_rpn_box_reg: 0.0521 (0.0597)  time: 0.7012  data: 0.0176  max mem: 4551
# Epoch: [0]  [690/752]  eta: 0:00:43  lr: 0.000920  loss: 0.6656 (0.6831)  loss_classifier: 0.1785 (0.1890)  loss_box_reg: 0.3917 (0.3986)  loss_objectness: 0.0259 (0.0357)  loss_rpn_box_reg: 0.0537 (0.0597)  time: 0.6966  data: 0.0177  max mem: 4551
# Epoch: [0]  [700/752]  eta: 0:00:36  lr: 0.000933  loss: 0.6782 (0.6832)  loss_classifier: 0.1870 (0.1890)  loss_box_reg: 0.3951 (0.3988)  loss_objectness: 0.0259 (0.0358)  loss_rpn_box_reg: 0.0550 (0.0597)  time: 0.6965  data: 0.0166  max mem: 4551
# Epoch: [0]  [710/752]  eta: 0:00:29  lr: 0.000947  loss: 0.7037 (0.6837)  loss_classifier: 0.1966 (0.1891)  loss_box_reg: 0.4032 (0.3990)  loss_objectness: 0.0353 (0.0359)  loss_rpn_box_reg: 0.0641 (0.0598)  time: 0.7006  data: 0.0165  max mem: 4551
# Epoch: [0]  [720/752]  eta: 0:00:22  lr: 0.000960  loss: 0.7225 (0.6842)  loss_classifier: 0.1995 (0.1892)  loss_box_reg: 0.4032 (0.3991)  loss_objectness: 0.0365 (0.0360)  loss_rpn_box_reg: 0.0617 (0.0599)  time: 0.7024  data: 0.0170  max mem: 4551
# Epoch: [0]  [730/752]  eta: 0:00:15  lr: 0.000973  loss: 0.7023 (0.6844)  loss_classifier: 0.1958 (0.1893)  loss_box_reg: 0.4019 (0.3992)  loss_objectness: 0.0344 (0.0359)  loss_rpn_box_reg: 0.0589 (0.0599)  time: 0.7022  data: 0.0167  max mem: 4551
# Epoch: [0]  [740/752]  eta: 0:00:08  lr: 0.000987  loss: 0.6781 (0.6847)  loss_classifier: 0.2025 (0.1896)  loss_box_reg: 0.3971 (0.3993)  loss_objectness: 0.0326 (0.0359)  loss_rpn_box_reg: 0.0574 (0.0599)  time: 0.7007  data: 0.0164  max mem: 4551
# Epoch: [0]  [750/752]  eta: 0:00:01  lr: 0.001000  loss: 0.6781 (0.6845)  loss_classifier: 0.1953 (0.1895)  loss_box_reg: 0.3918 (0.3991)  loss_objectness: 0.0285 (0.0359)  loss_rpn_box_reg: 0.0557 (0.0600)  time: 0.6926  data: 0.0163  max mem: 4551
# Epoch: [0]  [751/752]  eta: 0:00:00  lr: 0.001000  loss: 0.6858 (0.6852)  loss_classifier: 0.1952 (0.1895)  loss_box_reg: 0.3902 (0.3991)  loss_objectness: 0.0296 (0.0365)  loss_rpn_box_reg: 0.0574 (0.0602)  time: 0.6671  data: 0.0158  max mem: 4551
# Epoch: [0] Total time: 0:08:46 (0.7003 s / it)
# creating index...
# index created!
# Test:  [ 0/92]  eta: 0:02:13  model_time: 0.3633 (0.3633)  evaluator_time: 0.4085 (0.4085)  time: 1.4473  data: 0.6476  max mem: 4551
# Test:  [91/92]  eta: 0:00:00  model_time: 0.2719 (0.2731)  evaluator_time: 0.2673 (0.2768)  time: 0.5682  data: 0.0154  max mem: 4551
# Test: Total time: 0:00:54 (0.5895 s / it)
# Averaged stats: model_time: 0.2719 (0.2731)  evaluator_time: 0.2673 (0.2768)
# Accumulating evaluation results...
# DONE (t=0.22s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.505
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.497
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.098
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.499
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.547
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.155
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.567
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.145
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.607
# Epoch: [1]  [  0/752]  eta: 0:27:04  lr: 0.001000  loss: 0.7299 (0.7299)  loss_classifier: 0.2100 (0.2100)  loss_box_reg: 0.4232 (0.4232)  loss_objectness: 0.0326 (0.0326)  loss_rpn_box_reg: 0.0641 (0.0641)  time: 2.1606  data: 1.2888  max mem: 4551
# Epoch: [1]  [ 10/752]  eta: 0:10:21  lr: 0.001000  loss: 0.6864 (0.6939)  loss_classifier: 0.1865 (0.1803)  loss_box_reg: 0.3722 (0.3849)  loss_objectness: 0.0409 (0.0484)  loss_rpn_box_reg: 0.0604 (0.0803)  time: 0.8373  data: 0.1296  max mem: 4551
# Epoch: [1]  [ 20/752]  eta: 0:09:26  lr: 0.001000  loss: 0.6759 (0.6826)  loss_classifier: 0.1773 (0.1731)  loss_box_reg: 0.3722 (0.3803)  loss_objectness: 0.0418 (0.0541)  loss_rpn_box_reg: 0.0563 (0.0751)  time: 0.7039  data: 0.0153  max mem: 4551
# Epoch: [1]  [ 30/752]  eta: 0:08:59  lr: 0.001000  loss: 0.6951 (0.7039)  loss_classifier: 0.1773 (0.1833)  loss_box_reg: 0.4110 (0.3982)  loss_objectness: 0.0421 (0.0504)  loss_rpn_box_reg: 0.0552 (0.0720)  time: 0.6983  data: 0.0165  max mem: 4551
# Epoch: [1]  [ 40/752]  eta: 0:08:42  lr: 0.001000  loss: 0.6931 (0.6897)  loss_classifier: 0.1800 (0.1800)  loss_box_reg: 0.4110 (0.3917)  loss_objectness: 0.0381 (0.0475)  loss_rpn_box_reg: 0.0583 (0.0705)  time: 0.6920  data: 0.0158  max mem: 4551
# Epoch: [1]  [ 50/752]  eta: 0:08:29  lr: 0.001000  loss: 0.6474 (0.6917)  loss_classifier: 0.1765 (0.1827)  loss_box_reg: 0.3880 (0.3918)  loss_objectness: 0.0337 (0.0459)  loss_rpn_box_reg: 0.0579 (0.0713)  time: 0.6926  data: 0.0156  max mem: 4551
# Epoch: [1]  [ 60/752]  eta: 0:08:19  lr: 0.001000  loss: 0.6679 (0.6879)  loss_classifier: 0.1769 (0.1820)  loss_box_reg: 0.3779 (0.3896)  loss_objectness: 0.0368 (0.0452)  loss_rpn_box_reg: 0.0583 (0.0711)  time: 0.6980  data: 0.0159  max mem: 4551
# Epoch: [1]  [ 70/752]  eta: 0:08:09  lr: 0.001000  loss: 0.6519 (0.6854)  loss_classifier: 0.1769 (0.1826)  loss_box_reg: 0.3854 (0.3913)  loss_objectness: 0.0277 (0.0427)  loss_rpn_box_reg: 0.0542 (0.0689)  time: 0.6987  data: 0.0159  max mem: 4551
# Epoch: [1]  [ 80/752]  eta: 0:08:00  lr: 0.001000  loss: 0.6549 (0.6851)  loss_classifier: 0.1859 (0.1839)  loss_box_reg: 0.3906 (0.3921)  loss_objectness: 0.0281 (0.0418)  loss_rpn_box_reg: 0.0517 (0.0673)  time: 0.6950  data: 0.0161  max mem: 4551
# Epoch: [1]  [ 90/752]  eta: 0:07:52  lr: 0.001000  loss: 0.6839 (0.6863)  loss_classifier: 0.1874 (0.1851)  loss_box_reg: 0.3922 (0.3928)  loss_objectness: 0.0376 (0.0418)  loss_rpn_box_reg: 0.0585 (0.0666)  time: 0.6945  data: 0.0161  max mem: 4551
# Epoch: [1]  [100/752]  eta: 0:07:43  lr: 0.001000  loss: 0.7016 (0.6867)  loss_classifier: 0.1863 (0.1854)  loss_box_reg: 0.4048 (0.3937)  loss_objectness: 0.0382 (0.0412)  loss_rpn_box_reg: 0.0593 (0.0664)  time: 0.6958  data: 0.0158  max mem: 4551
# Epoch: [1]  [110/752]  eta: 0:07:35  lr: 0.001000  loss: 0.6783 (0.6864)  loss_classifier: 0.1844 (0.1856)  loss_box_reg: 0.4001 (0.3948)  loss_objectness: 0.0287 (0.0403)  loss_rpn_box_reg: 0.0577 (0.0657)  time: 0.6957  data: 0.0161  max mem: 4551
# Epoch: [1]  [120/752]  eta: 0:07:27  lr: 0.001000  loss: 0.6580 (0.6836)  loss_classifier: 0.1870 (0.1856)  loss_box_reg: 0.3865 (0.3936)  loss_objectness: 0.0271 (0.0392)  loss_rpn_box_reg: 0.0536 (0.0652)  time: 0.6952  data: 0.0161  max mem: 4551
# Epoch: [1]  [130/752]  eta: 0:07:20  lr: 0.001000  loss: 0.6580 (0.6859)  loss_classifier: 0.1776 (0.1861)  loss_box_reg: 0.3859 (0.3951)  loss_objectness: 0.0281 (0.0392)  loss_rpn_box_reg: 0.0577 (0.0655)  time: 0.6975  data: 0.0157  max mem: 4551
# Epoch: [1]  [140/752]  eta: 0:07:12  lr: 0.001000  loss: 0.6861 (0.6834)  loss_classifier: 0.1785 (0.1856)  loss_box_reg: 0.3899 (0.3945)  loss_objectness: 0.0289 (0.0384)  loss_rpn_box_reg: 0.0577 (0.0648)  time: 0.6993  data: 0.0162  max mem: 4551
# Epoch: [1]  [150/752]  eta: 0:07:05  lr: 0.001000  loss: 0.6811 (0.6835)  loss_classifier: 0.1801 (0.1856)  loss_box_reg: 0.3807 (0.3943)  loss_objectness: 0.0289 (0.0383)  loss_rpn_box_reg: 0.0559 (0.0654)  time: 0.6962  data: 0.0161  max mem: 4551
# Epoch: [1]  [160/752]  eta: 0:06:57  lr: 0.001000  loss: 0.6824 (0.6855)  loss_classifier: 0.1801 (0.1859)  loss_box_reg: 0.3852 (0.3954)  loss_objectness: 0.0324 (0.0389)  loss_rpn_box_reg: 0.0632 (0.0654)  time: 0.6953  data: 0.0159  max mem: 4551
# Epoch: [1]  [170/752]  eta: 0:06:50  lr: 0.001000  loss: 0.6730 (0.6840)  loss_classifier: 0.1933 (0.1860)  loss_box_reg: 0.3852 (0.3949)  loss_objectness: 0.0317 (0.0382)  loss_rpn_box_reg: 0.0555 (0.0648)  time: 0.6980  data: 0.0160  max mem: 4551
# Epoch: [1]  [180/752]  eta: 0:06:43  lr: 0.001000  loss: 0.6730 (0.6834)  loss_classifier: 0.1825 (0.1854)  loss_box_reg: 0.3915 (0.3947)  loss_objectness: 0.0288 (0.0383)  loss_rpn_box_reg: 0.0555 (0.0650)  time: 0.6969  data: 0.0157  max mem: 4551
# Epoch: [1]  [190/752]  eta: 0:06:36  lr: 0.001000  loss: 0.6974 (0.6826)  loss_classifier: 0.1784 (0.1852)  loss_box_reg: 0.4026 (0.3949)  loss_objectness: 0.0273 (0.0380)  loss_rpn_box_reg: 0.0579 (0.0645)  time: 0.6985  data: 0.0166  max mem: 4551
# Epoch: [1]  [200/752]  eta: 0:06:28  lr: 0.001000  loss: 0.6949 (0.6830)  loss_classifier: 0.1831 (0.1856)  loss_box_reg: 0.4069 (0.3952)  loss_objectness: 0.0256 (0.0380)  loss_rpn_box_reg: 0.0527 (0.0642)  time: 0.6995  data: 0.0169  max mem: 4551
# Epoch: [1]  [210/752]  eta: 0:06:21  lr: 0.001000  loss: 0.6625 (0.6810)  loss_classifier: 0.1858 (0.1852)  loss_box_reg: 0.3893 (0.3943)  loss_objectness: 0.0331 (0.0378)  loss_rpn_box_reg: 0.0517 (0.0637)  time: 0.6987  data: 0.0172  max mem: 4551
# Epoch: [1]  [220/752]  eta: 0:06:14  lr: 0.001000  loss: 0.6719 (0.6831)  loss_classifier: 0.1858 (0.1859)  loss_box_reg: 0.4099 (0.3955)  loss_objectness: 0.0331 (0.0378)  loss_rpn_box_reg: 0.0605 (0.0639)  time: 0.7002  data: 0.0177  max mem: 4551
# Epoch: [1]  [230/752]  eta: 0:06:07  lr: 0.001000  loss: 0.7241 (0.6831)  loss_classifier: 0.1894 (0.1861)  loss_box_reg: 0.4071 (0.3954)  loss_objectness: 0.0374 (0.0377)  loss_rpn_box_reg: 0.0625 (0.0639)  time: 0.7016  data: 0.0177  max mem: 4551
# Epoch: [1]  [240/752]  eta: 0:06:00  lr: 0.001000  loss: 0.7073 (0.6841)  loss_classifier: 0.1970 (0.1867)  loss_box_reg: 0.4013 (0.3957)  loss_objectness: 0.0357 (0.0377)  loss_rpn_box_reg: 0.0620 (0.0640)  time: 0.7011  data: 0.0175  max mem: 4551
# Epoch: [1]  [250/752]  eta: 0:05:53  lr: 0.001000  loss: 0.7369 (0.6861)  loss_classifier: 0.2045 (0.1873)  loss_box_reg: 0.4227 (0.3970)  loss_objectness: 0.0357 (0.0376)  loss_rpn_box_reg: 0.0627 (0.0642)  time: 0.6983  data: 0.0167  max mem: 4551
# Epoch: [1]  [260/752]  eta: 0:05:45  lr: 0.001000  loss: 0.6962 (0.6849)  loss_classifier: 0.1919 (0.1871)  loss_box_reg: 0.4103 (0.3966)  loss_objectness: 0.0301 (0.0374)  loss_rpn_box_reg: 0.0584 (0.0638)  time: 0.6964  data: 0.0158  max mem: 4551
# Epoch: [1]  [270/752]  eta: 0:05:38  lr: 0.001000  loss: 0.6708 (0.6859)  loss_classifier: 0.1842 (0.1877)  loss_box_reg: 0.4028 (0.3972)  loss_objectness: 0.0272 (0.0374)  loss_rpn_box_reg: 0.0529 (0.0636)  time: 0.6948  data: 0.0161  max mem: 4551
# Epoch: [1]  [280/752]  eta: 0:05:31  lr: 0.001000  loss: 0.6708 (0.6855)  loss_classifier: 0.1930 (0.1879)  loss_box_reg: 0.4020 (0.3970)  loss_objectness: 0.0294 (0.0372)  loss_rpn_box_reg: 0.0560 (0.0634)  time: 0.6965  data: 0.0175  max mem: 4551
# Epoch: [1]  [290/752]  eta: 0:05:24  lr: 0.001000  loss: 0.6861 (0.6862)  loss_classifier: 0.1959 (0.1882)  loss_box_reg: 0.3848 (0.3974)  loss_objectness: 0.0293 (0.0371)  loss_rpn_box_reg: 0.0571 (0.0635)  time: 0.7001  data: 0.0181  max mem: 4551
# Epoch: [1]  [300/752]  eta: 0:05:17  lr: 0.001000  loss: 0.6597 (0.6851)  loss_classifier: 0.1851 (0.1879)  loss_box_reg: 0.3822 (0.3970)  loss_objectness: 0.0279 (0.0370)  loss_rpn_box_reg: 0.0555 (0.0632)  time: 0.7005  data: 0.0171  max mem: 4551
# Epoch: [1]  [310/752]  eta: 0:05:10  lr: 0.001000  loss: 0.6101 (0.6843)  loss_classifier: 0.1741 (0.1878)  loss_box_reg: 0.3754 (0.3969)  loss_objectness: 0.0271 (0.0367)  loss_rpn_box_reg: 0.0528 (0.0629)  time: 0.6976  data: 0.0160  max mem: 4551
# Epoch: [1]  [320/752]  eta: 0:05:03  lr: 0.001000  loss: 0.6426 (0.6838)  loss_classifier: 0.1825 (0.1876)  loss_box_reg: 0.3896 (0.3970)  loss_objectness: 0.0273 (0.0365)  loss_rpn_box_reg: 0.0556 (0.0627)  time: 0.6985  data: 0.0158  max mem: 4551
# Epoch: [1]  [330/752]  eta: 0:04:56  lr: 0.001000  loss: 0.6809 (0.6835)  loss_classifier: 0.1881 (0.1875)  loss_box_reg: 0.4048 (0.3971)  loss_objectness: 0.0299 (0.0364)  loss_rpn_box_reg: 0.0582 (0.0625)  time: 0.6982  data: 0.0159  max mem: 4551
# Epoch: [1]  [340/752]  eta: 0:04:49  lr: 0.001000  loss: 0.6845 (0.6833)  loss_classifier: 0.1875 (0.1876)  loss_box_reg: 0.4016 (0.3968)  loss_objectness: 0.0297 (0.0364)  loss_rpn_box_reg: 0.0584 (0.0626)  time: 0.6958  data: 0.0161  max mem: 4551
# Epoch: [1]  [350/752]  eta: 0:04:42  lr: 0.001000  loss: 0.6658 (0.6827)  loss_classifier: 0.1875 (0.1876)  loss_box_reg: 0.3863 (0.3966)  loss_objectness: 0.0246 (0.0363)  loss_rpn_box_reg: 0.0546 (0.0622)  time: 0.6952  data: 0.0163  max mem: 4551
# Epoch: [1]  [360/752]  eta: 0:04:35  lr: 0.001000  loss: 0.6658 (0.6824)  loss_classifier: 0.1866 (0.1875)  loss_box_reg: 0.3863 (0.3964)  loss_objectness: 0.0301 (0.0362)  loss_rpn_box_reg: 0.0568 (0.0622)  time: 0.6952  data: 0.0158  max mem: 4551
# Epoch: [1]  [370/752]  eta: 0:04:27  lr: 0.001000  loss: 0.6516 (0.6824)  loss_classifier: 0.1783 (0.1878)  loss_box_reg: 0.4090 (0.3967)  loss_objectness: 0.0249 (0.0358)  loss_rpn_box_reg: 0.0568 (0.0621)  time: 0.6962  data: 0.0158  max mem: 4551
# Epoch: [1]  [380/752]  eta: 0:04:20  lr: 0.001000  loss: 0.7020 (0.6834)  loss_classifier: 0.2027 (0.1882)  loss_box_reg: 0.4172 (0.3975)  loss_objectness: 0.0249 (0.0357)  loss_rpn_box_reg: 0.0550 (0.0620)  time: 0.6944  data: 0.0160  max mem: 4551
# Epoch: [1]  [390/752]  eta: 0:04:13  lr: 0.001000  loss: 0.7054 (0.6842)  loss_classifier: 0.2039 (0.1885)  loss_box_reg: 0.4172 (0.3977)  loss_objectness: 0.0353 (0.0360)  loss_rpn_box_reg: 0.0575 (0.0620)  time: 0.6935  data: 0.0161  max mem: 4551
# Epoch: [1]  [400/752]  eta: 0:04:06  lr: 0.001000  loss: 0.7160 (0.6846)  loss_classifier: 0.1989 (0.1889)  loss_box_reg: 0.4167 (0.3980)  loss_objectness: 0.0368 (0.0359)  loss_rpn_box_reg: 0.0568 (0.0619)  time: 0.6945  data: 0.0165  max mem: 4551
# Epoch: [1]  [410/752]  eta: 0:03:59  lr: 0.001000  loss: 0.7217 (0.6854)  loss_classifier: 0.1989 (0.1893)  loss_box_reg: 0.4167 (0.3985)  loss_objectness: 0.0309 (0.0358)  loss_rpn_box_reg: 0.0585 (0.0619)  time: 0.6972  data: 0.0165  max mem: 4551
# Epoch: [1]  [420/752]  eta: 0:03:52  lr: 0.001000  loss: 0.7299 (0.6863)  loss_classifier: 0.2076 (0.1898)  loss_box_reg: 0.4160 (0.3989)  loss_objectness: 0.0299 (0.0359)  loss_rpn_box_reg: 0.0568 (0.0617)  time: 0.6952  data: 0.0159  max mem: 4551
# Epoch: [1]  [430/752]  eta: 0:03:45  lr: 0.001000  loss: 0.7008 (0.6861)  loss_classifier: 0.1967 (0.1899)  loss_box_reg: 0.4090 (0.3989)  loss_objectness: 0.0276 (0.0357)  loss_rpn_box_reg: 0.0558 (0.0616)  time: 0.6927  data: 0.0159  max mem: 4551
# Epoch: [1]  [440/752]  eta: 0:03:38  lr: 0.001000  loss: 0.7051 (0.6862)  loss_classifier: 0.1946 (0.1901)  loss_box_reg: 0.4184 (0.3988)  loss_objectness: 0.0294 (0.0357)  loss_rpn_box_reg: 0.0589 (0.0616)  time: 0.6940  data: 0.0160  max mem: 4551
# Epoch: [1]  [450/752]  eta: 0:03:31  lr: 0.001000  loss: 0.7141 (0.6867)  loss_classifier: 0.2019 (0.1904)  loss_box_reg: 0.4131 (0.3987)  loss_objectness: 0.0384 (0.0361)  loss_rpn_box_reg: 0.0609 (0.0616)  time: 0.6944  data: 0.0165  max mem: 4551
# Epoch: [1]  [460/752]  eta: 0:03:24  lr: 0.001000  loss: 0.7030 (0.6871)  loss_classifier: 0.2019 (0.1906)  loss_box_reg: 0.3923 (0.3989)  loss_objectness: 0.0395 (0.0361)  loss_rpn_box_reg: 0.0580 (0.0614)  time: 0.6944  data: 0.0167  max mem: 4551
# Epoch: [1]  [470/752]  eta: 0:03:17  lr: 0.001000  loss: 0.6646 (0.6861)  loss_classifier: 0.1869 (0.1903)  loss_box_reg: 0.3846 (0.3985)  loss_objectness: 0.0311 (0.0360)  loss_rpn_box_reg: 0.0499 (0.0613)  time: 0.6948  data: 0.0161  max mem: 4551
# Epoch: [1]  [480/752]  eta: 0:03:10  lr: 0.001000  loss: 0.6556 (0.6857)  loss_classifier: 0.1756 (0.1901)  loss_box_reg: 0.3846 (0.3986)  loss_objectness: 0.0287 (0.0359)  loss_rpn_box_reg: 0.0524 (0.0612)  time: 0.6969  data: 0.0158  max mem: 4551
# Epoch: [1]  [490/752]  eta: 0:03:03  lr: 0.001000  loss: 0.6868 (0.6867)  loss_classifier: 0.1800 (0.1904)  loss_box_reg: 0.4129 (0.3992)  loss_objectness: 0.0322 (0.0359)  loss_rpn_box_reg: 0.0563 (0.0612)  time: 0.6972  data: 0.0160  max mem: 4551
# Epoch: [1]  [500/752]  eta: 0:02:56  lr: 0.001000  loss: 0.6868 (0.6859)  loss_classifier: 0.1910 (0.1903)  loss_box_reg: 0.4110 (0.3990)  loss_objectness: 0.0312 (0.0357)  loss_rpn_box_reg: 0.0545 (0.0609)  time: 0.6965  data: 0.0158  max mem: 4551
# Epoch: [1]  [510/752]  eta: 0:02:49  lr: 0.001000  loss: 0.6926 (0.6863)  loss_classifier: 0.1894 (0.1903)  loss_box_reg: 0.4198 (0.3994)  loss_objectness: 0.0272 (0.0357)  loss_rpn_box_reg: 0.0534 (0.0609)  time: 0.6975  data: 0.0160  max mem: 4551
# Epoch: [1]  [520/752]  eta: 0:02:42  lr: 0.001000  loss: 0.7077 (0.6862)  loss_classifier: 0.1894 (0.1902)  loss_box_reg: 0.4198 (0.3994)  loss_objectness: 0.0325 (0.0357)  loss_rpn_box_reg: 0.0609 (0.0610)  time: 0.6976  data: 0.0163  max mem: 4551
# Epoch: [1]  [530/752]  eta: 0:02:35  lr: 0.001000  loss: 0.7185 (0.6871)  loss_classifier: 0.1970 (0.1904)  loss_box_reg: 0.4232 (0.3999)  loss_objectness: 0.0320 (0.0357)  loss_rpn_box_reg: 0.0626 (0.0610)  time: 0.6960  data: 0.0162  max mem: 4551
# Epoch: [1]  [540/752]  eta: 0:02:28  lr: 0.001000  loss: 0.7185 (0.6871)  loss_classifier: 0.1996 (0.1903)  loss_box_reg: 0.4230 (0.4000)  loss_objectness: 0.0250 (0.0358)  loss_rpn_box_reg: 0.0580 (0.0610)  time: 0.6967  data: 0.0159  max mem: 4551
# Epoch: [1]  [550/752]  eta: 0:02:21  lr: 0.001000  loss: 0.6599 (0.6867)  loss_classifier: 0.1914 (0.1902)  loss_box_reg: 0.4108 (0.3999)  loss_objectness: 0.0271 (0.0358)  loss_rpn_box_reg: 0.0543 (0.0608)  time: 0.6981  data: 0.0158  max mem: 4551
# Epoch: [1]  [560/752]  eta: 0:02:14  lr: 0.001000  loss: 0.6696 (0.6864)  loss_classifier: 0.1851 (0.1902)  loss_box_reg: 0.3977 (0.3997)  loss_objectness: 0.0354 (0.0358)  loss_rpn_box_reg: 0.0543 (0.0607)  time: 0.6962  data: 0.0159  max mem: 4551
# Epoch: [1]  [570/752]  eta: 0:02:07  lr: 0.001000  loss: 0.6752 (0.6867)  loss_classifier: 0.1881 (0.1903)  loss_box_reg: 0.3862 (0.3998)  loss_objectness: 0.0333 (0.0358)  loss_rpn_box_reg: 0.0578 (0.0608)  time: 0.6978  data: 0.0161  max mem: 4551
# Epoch: [1]  [580/752]  eta: 0:02:00  lr: 0.001000  loss: 0.7028 (0.6870)  loss_classifier: 0.1970 (0.1904)  loss_box_reg: 0.3998 (0.4001)  loss_objectness: 0.0318 (0.0358)  loss_rpn_box_reg: 0.0581 (0.0608)  time: 0.6988  data: 0.0163  max mem: 4551
# Epoch: [1]  [590/752]  eta: 0:01:53  lr: 0.001000  loss: 0.7183 (0.6879)  loss_classifier: 0.2047 (0.1906)  loss_box_reg: 0.4091 (0.4004)  loss_objectness: 0.0415 (0.0359)  loss_rpn_box_reg: 0.0568 (0.0610)  time: 0.6964  data: 0.0163  max mem: 4551
# Epoch: [1]  [600/752]  eta: 0:01:46  lr: 0.001000  loss: 0.7183 (0.6881)  loss_classifier: 0.2019 (0.1908)  loss_box_reg: 0.4091 (0.4005)  loss_objectness: 0.0417 (0.0359)  loss_rpn_box_reg: 0.0561 (0.0609)  time: 0.6972  data: 0.0167  max mem: 4551
# Epoch: [1]  [610/752]  eta: 0:01:39  lr: 0.001000  loss: 0.6310 (0.6877)  loss_classifier: 0.1803 (0.1906)  loss_box_reg: 0.3819 (0.4003)  loss_objectness: 0.0294 (0.0358)  loss_rpn_box_reg: 0.0547 (0.0610)  time: 0.6980  data: 0.0167  max mem: 4551
# Epoch: [1]  [620/752]  eta: 0:01:32  lr: 0.001000  loss: 0.6731 (0.6877)  loss_classifier: 0.1827 (0.1906)  loss_box_reg: 0.3781 (0.4001)  loss_objectness: 0.0294 (0.0359)  loss_rpn_box_reg: 0.0547 (0.0611)  time: 0.6984  data: 0.0165  max mem: 4551
# Epoch: [1]  [630/752]  eta: 0:01:25  lr: 0.001000  loss: 0.6731 (0.6879)  loss_classifier: 0.1893 (0.1907)  loss_box_reg: 0.3802 (0.4003)  loss_objectness: 0.0339 (0.0358)  loss_rpn_box_reg: 0.0552 (0.0610)  time: 0.6991  data: 0.0173  max mem: 4551
# Epoch: [1]  [640/752]  eta: 0:01:18  lr: 0.001000  loss: 0.6610 (0.6875)  loss_classifier: 0.1942 (0.1906)  loss_box_reg: 0.4144 (0.4001)  loss_objectness: 0.0328 (0.0358)  loss_rpn_box_reg: 0.0552 (0.0609)  time: 0.7024  data: 0.0174  max mem: 4551
# Epoch: [1]  [650/752]  eta: 0:01:11  lr: 0.001000  loss: 0.6494 (0.6870)  loss_classifier: 0.1738 (0.1905)  loss_box_reg: 0.3876 (0.3999)  loss_objectness: 0.0300 (0.0357)  loss_rpn_box_reg: 0.0495 (0.0608)  time: 0.7013  data: 0.0171  max mem: 4551
# Epoch: [1]  [660/752]  eta: 0:01:04  lr: 0.001000  loss: 0.6494 (0.6865)  loss_classifier: 0.1721 (0.1905)  loss_box_reg: 0.3877 (0.3998)  loss_objectness: 0.0283 (0.0356)  loss_rpn_box_reg: 0.0495 (0.0607)  time: 0.6957  data: 0.0169  max mem: 4551
# Epoch: [1]  [670/752]  eta: 0:00:57  lr: 0.001000  loss: 0.7011 (0.6869)  loss_classifier: 0.2054 (0.1907)  loss_box_reg: 0.3977 (0.4000)  loss_objectness: 0.0270 (0.0355)  loss_rpn_box_reg: 0.0585 (0.0606)  time: 0.6975  data: 0.0167  max mem: 4551
# Epoch: [1]  [680/752]  eta: 0:00:50  lr: 0.001000  loss: 0.6913 (0.6863)  loss_classifier: 0.1819 (0.1906)  loss_box_reg: 0.3933 (0.3997)  loss_objectness: 0.0268 (0.0354)  loss_rpn_box_reg: 0.0531 (0.0605)  time: 0.6989  data: 0.0168  max mem: 4551
# Epoch: [1]  [690/752]  eta: 0:00:43  lr: 0.001000  loss: 0.6567 (0.6861)  loss_classifier: 0.1759 (0.1905)  loss_box_reg: 0.3838 (0.3997)  loss_objectness: 0.0273 (0.0355)  loss_rpn_box_reg: 0.0531 (0.0604)  time: 0.6974  data: 0.0167  max mem: 4551
# Epoch: [1]  [700/752]  eta: 0:00:36  lr: 0.001000  loss: 0.6645 (0.6863)  loss_classifier: 0.1973 (0.1906)  loss_box_reg: 0.4005 (0.3997)  loss_objectness: 0.0356 (0.0355)  loss_rpn_box_reg: 0.0551 (0.0604)  time: 0.7038  data: 0.0174  max mem: 4551
# Epoch: [1]  [710/752]  eta: 0:00:29  lr: 0.001000  loss: 0.6787 (0.6861)  loss_classifier: 0.1973 (0.1905)  loss_box_reg: 0.3897 (0.3996)  loss_objectness: 0.0349 (0.0355)  loss_rpn_box_reg: 0.0534 (0.0604)  time: 0.7044  data: 0.0177  max mem: 4551
# Epoch: [1]  [720/752]  eta: 0:00:22  lr: 0.001000  loss: 0.6804 (0.6866)  loss_classifier: 0.1916 (0.1907)  loss_box_reg: 0.3969 (0.3998)  loss_objectness: 0.0329 (0.0356)  loss_rpn_box_reg: 0.0609 (0.0606)  time: 0.7004  data: 0.0175  max mem: 4551
# Epoch: [1]  [730/752]  eta: 0:00:15  lr: 0.001000  loss: 0.6990 (0.6867)  loss_classifier: 0.1867 (0.1907)  loss_box_reg: 0.4061 (0.3999)  loss_objectness: 0.0306 (0.0356)  loss_rpn_box_reg: 0.0547 (0.0606)  time: 0.7005  data: 0.0182  max mem: 4551
# Epoch: [1]  [740/752]  eta: 0:00:08  lr: 0.001000  loss: 0.6368 (0.6859)  loss_classifier: 0.1806 (0.1904)  loss_box_reg: 0.3790 (0.3993)  loss_objectness: 0.0292 (0.0355)  loss_rpn_box_reg: 0.0544 (0.0606)  time: 0.7000  data: 0.0182  max mem: 4551
# Epoch: [1]  [750/752]  eta: 0:00:01  lr: 0.001000  loss: 0.6538 (0.6858)  loss_classifier: 0.1808 (0.1905)  loss_box_reg: 0.3856 (0.3994)  loss_objectness: 0.0261 (0.0355)  loss_rpn_box_reg: 0.0546 (0.0605)  time: 0.6949  data: 0.0171  max mem: 4551
# Epoch: [1]  [751/752]  eta: 0:00:00  lr: 0.001000  loss: 0.6579 (0.6858)  loss_classifier: 0.1824 (0.1905)  loss_box_reg: 0.3902 (0.3994)  loss_objectness: 0.0276 (0.0355)  loss_rpn_box_reg: 0.0541 (0.0605)  time: 0.6703  data: 0.0166  max mem: 4551
# Epoch: [1] Total time: 0:08:45 (0.6989 s / it)
# creating index...
# index created!
# Test:  [ 0/92]  eta: 0:02:17  model_time: 0.3773 (0.3773)  evaluator_time: 0.2615 (0.2615)  time: 1.4982  data: 0.8340  max mem: 4551
# Test:  [91/92]  eta: 0:00:00  model_time: 0.2715 (0.2733)  evaluator_time: 0.2732 (0.2812)  time: 0.5740  data: 0.0161  max mem: 4551
# Test: Total time: 0:00:54 (0.5975 s / it)
# Averaged stats: model_time: 0.2715 (0.2733)  evaluator_time: 0.2732 (0.2812)
# Accumulating evaluation results...
# DONE (t=0.21s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.509
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.924
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.507
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.503
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.546
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.156
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.570
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.141
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.600
# Epoch: [2]  [  0/752]  eta: 0:25:59  lr: 0.001000  loss: 0.7454 (0.7454)  loss_classifier: 0.2216 (0.2216)  loss_box_reg: 0.4449 (0.4449)  loss_objectness: 0.0231 (0.0231)  loss_rpn_box_reg: 0.0557 (0.0557)  time: 2.0742  data: 1.1882  max mem: 4551
# Epoch: [2]  [ 10/752]  eta: 0:10:21  lr: 0.001000  loss: 0.6920 (0.6811)  loss_classifier: 0.1976 (0.1965)  loss_box_reg: 0.3970 (0.3944)  loss_objectness: 0.0319 (0.0346)  loss_rpn_box_reg: 0.0557 (0.0555)  time: 0.8371  data: 0.1214  max mem: 4551
# Epoch: [2]  [ 20/752]  eta: 0:09:28  lr: 0.001000  loss: 0.6740 (0.6716)  loss_classifier: 0.1921 (0.1890)  loss_box_reg: 0.3888 (0.3950)  loss_objectness: 0.0300 (0.0316)  loss_rpn_box_reg: 0.0553 (0.0560)  time: 0.7120  data: 0.0162  max mem: 4551
# Epoch: [2]  [ 30/752]  eta: 0:09:02  lr: 0.001000  loss: 0.6598 (0.6715)  loss_classifier: 0.1743 (0.1854)  loss_box_reg: 0.3750 (0.3916)  loss_objectness: 0.0281 (0.0345)  loss_rpn_box_reg: 0.0535 (0.0600)  time: 0.7037  data: 0.0165  max mem: 4551
# Epoch: [2]  [ 40/752]  eta: 0:08:45  lr: 0.001000  loss: 0.6598 (0.6780)  loss_classifier: 0.1743 (0.1862)  loss_box_reg: 0.3945 (0.3935)  loss_objectness: 0.0334 (0.0358)  loss_rpn_box_reg: 0.0553 (0.0625)  time: 0.6982  data: 0.0157  max mem: 4551
# Epoch: [2]  [ 50/752]  eta: 0:08:32  lr: 0.001000  loss: 0.6880 (0.6770)  loss_classifier: 0.1874 (0.1865)  loss_box_reg: 0.4009 (0.3940)  loss_objectness: 0.0278 (0.0352)  loss_rpn_box_reg: 0.0572 (0.0614)  time: 0.6974  data: 0.0157  max mem: 4551
# Epoch: [2]  [ 60/752]  eta: 0:08:21  lr: 0.001000  loss: 0.6567 (0.6755)  loss_classifier: 0.1922 (0.1865)  loss_box_reg: 0.3892 (0.3932)  loss_objectness: 0.0274 (0.0351)  loss_rpn_box_reg: 0.0544 (0.0606)  time: 0.6956  data: 0.0153  max mem: 4551
# Epoch: [2]  [ 70/752]  eta: 0:08:11  lr: 0.001000  loss: 0.6382 (0.6707)  loss_classifier: 0.1777 (0.1850)  loss_box_reg: 0.3708 (0.3922)  loss_objectness: 0.0243 (0.0339)  loss_rpn_box_reg: 0.0537 (0.0596)  time: 0.6982  data: 0.0164  max mem: 4551
# Epoch: [2]  [ 80/752]  eta: 0:08:02  lr: 0.001000  loss: 0.6766 (0.6724)  loss_classifier: 0.1800 (0.1868)  loss_box_reg: 0.3974 (0.3930)  loss_objectness: 0.0270 (0.0338)  loss_rpn_box_reg: 0.0526 (0.0588)  time: 0.7006  data: 0.0174  max mem: 4551
# Epoch: [2]  [ 90/752]  eta: 0:07:54  lr: 0.001000  loss: 0.7023 (0.6742)  loss_classifier: 0.1993 (0.1878)  loss_box_reg: 0.4092 (0.3948)  loss_objectness: 0.0261 (0.0333)  loss_rpn_box_reg: 0.0505 (0.0583)  time: 0.6987  data: 0.0168  max mem: 4551
# Epoch: [2]  [100/752]  eta: 0:07:45  lr: 0.001000  loss: 0.7145 (0.6788)  loss_classifier: 0.1993 (0.1892)  loss_box_reg: 0.4138 (0.3963)  loss_objectness: 0.0294 (0.0342)  loss_rpn_box_reg: 0.0528 (0.0591)  time: 0.6969  data: 0.0162  max mem: 4551
# Epoch: [2]  [110/752]  eta: 0:07:37  lr: 0.001000  loss: 0.6757 (0.6808)  loss_classifier: 0.1978 (0.1902)  loss_box_reg: 0.4003 (0.3976)  loss_objectness: 0.0311 (0.0342)  loss_rpn_box_reg: 0.0561 (0.0588)  time: 0.6984  data: 0.0160  max mem: 4551
# Epoch: [2]  [120/752]  eta: 0:07:29  lr: 0.001000  loss: 0.6757 (0.6842)  loss_classifier: 0.1978 (0.1910)  loss_box_reg: 0.4017 (0.3988)  loss_objectness: 0.0293 (0.0343)  loss_rpn_box_reg: 0.0561 (0.0600)  time: 0.6989  data: 0.0157  max mem: 4551
# Epoch: [2]  [130/752]  eta: 0:07:21  lr: 0.001000  loss: 0.6846 (0.6824)  loss_classifier: 0.1848 (0.1901)  loss_box_reg: 0.4017 (0.3977)  loss_objectness: 0.0306 (0.0345)  loss_rpn_box_reg: 0.0572 (0.0600)  time: 0.6974  data: 0.0155  max mem: 4551
# Epoch: [2]  [140/752]  eta: 0:07:14  lr: 0.001000  loss: 0.6467 (0.6810)  loss_classifier: 0.1805 (0.1899)  loss_box_reg: 0.3706 (0.3965)  loss_objectness: 0.0346 (0.0347)  loss_rpn_box_reg: 0.0532 (0.0599)  time: 0.6956  data: 0.0154  max mem: 4551
# Epoch: [2]  [150/752]  eta: 0:07:06  lr: 0.001000  loss: 0.6619 (0.6830)  loss_classifier: 0.1819 (0.1903)  loss_box_reg: 0.3873 (0.3980)  loss_objectness: 0.0346 (0.0350)  loss_rpn_box_reg: 0.0512 (0.0597)  time: 0.6962  data: 0.0156  max mem: 4551
# Epoch: [2]  [160/752]  eta: 0:06:59  lr: 0.001000  loss: 0.6622 (0.6827)  loss_classifier: 0.1885 (0.1902)  loss_box_reg: 0.4023 (0.3979)  loss_objectness: 0.0351 (0.0350)  loss_rpn_box_reg: 0.0498 (0.0595)  time: 0.6971  data: 0.0158  max mem: 4551
# Epoch: [2]  [170/752]  eta: 0:06:51  lr: 0.001000  loss: 0.6622 (0.6811)  loss_classifier: 0.1872 (0.1898)  loss_box_reg: 0.3972 (0.3970)  loss_objectness: 0.0334 (0.0350)  loss_rpn_box_reg: 0.0498 (0.0593)  time: 0.6947  data: 0.0161  max mem: 4551
# Epoch: [2]  [180/752]  eta: 0:06:44  lr: 0.001000  loss: 0.6695 (0.6816)  loss_classifier: 0.1872 (0.1899)  loss_box_reg: 0.3818 (0.3974)  loss_objectness: 0.0353 (0.0351)  loss_rpn_box_reg: 0.0543 (0.0592)  time: 0.6956  data: 0.0162  max mem: 4551
# Epoch: [2]  [190/752]  eta: 0:06:36  lr: 0.001000  loss: 0.6702 (0.6798)  loss_classifier: 0.1848 (0.1889)  loss_box_reg: 0.3794 (0.3967)  loss_objectness: 0.0322 (0.0352)  loss_rpn_box_reg: 0.0562 (0.0591)  time: 0.6975  data: 0.0160  max mem: 4551
# Epoch: [2]  [200/752]  eta: 0:06:29  lr: 0.001000  loss: 0.6493 (0.6798)  loss_classifier: 0.1727 (0.1889)  loss_box_reg: 0.3818 (0.3969)  loss_objectness: 0.0322 (0.0351)  loss_rpn_box_reg: 0.0559 (0.0589)  time: 0.6978  data: 0.0160  max mem: 4551
# Epoch: [2]  [210/752]  eta: 0:06:22  lr: 0.001000  loss: 0.6435 (0.6789)  loss_classifier: 0.1783 (0.1887)  loss_box_reg: 0.3935 (0.3968)  loss_objectness: 0.0258 (0.0347)  loss_rpn_box_reg: 0.0558 (0.0588)  time: 0.6972  data: 0.0162  max mem: 4551
# Epoch: [2]  [220/752]  eta: 0:06:14  lr: 0.001000  loss: 0.6881 (0.6779)  loss_classifier: 0.1775 (0.1881)  loss_box_reg: 0.3889 (0.3962)  loss_objectness: 0.0254 (0.0348)  loss_rpn_box_reg: 0.0566 (0.0588)  time: 0.6967  data: 0.0160  max mem: 4551
# Epoch: [2]  [230/752]  eta: 0:06:07  lr: 0.001000  loss: 0.6881 (0.6783)  loss_classifier: 0.1884 (0.1885)  loss_box_reg: 0.3889 (0.3963)  loss_objectness: 0.0273 (0.0348)  loss_rpn_box_reg: 0.0557 (0.0588)  time: 0.6988  data: 0.0163  max mem: 4551
# ...
# Epoch: [19]  [200/752]  eta: 0:06:29  lr: 0.000010  loss: 0.6350 (0.6313)  loss_classifier: 0.1872 (0.1759)  loss_box_reg: 0.3865 (0.3761)  loss_objectness: 0.0233 (0.0258)  loss_rpn_box_reg: 0.0546 (0.0536)  time: 0.6959  data: 0.0168  max mem: 4551
# Epoch: [19]  [210/752]  eta: 0:06:22  lr: 0.000010  loss: 0.6334 (0.6314)  loss_classifier: 0.1732 (0.1758)  loss_box_reg: 0.3761 (0.3764)  loss_objectness: 0.0285 (0.0258)  loss_rpn_box_reg: 0.0558 (0.0535)  time: 0.6985  data: 0.0163  max mem: 4551
# Epoch: [19]  [220/752]  eta: 0:06:14  lr: 0.000010  loss: 0.5988 (0.6294)  loss_classifier: 0.1653 (0.1752)  loss_box_reg: 0.3639 (0.3751)  loss_objectness: 0.0230 (0.0256)  loss_rpn_box_reg: 0.0512 (0.0535)  time: 0.6986  data: 0.0165  max mem: 4551
# Epoch: [19]  [230/752]  eta: 0:06:07  lr: 0.000010  loss: 0.5851 (0.6289)  loss_classifier: 0.1636 (0.1749)  loss_box_reg: 0.3382 (0.3746)  loss_objectness: 0.0263 (0.0260)  loss_rpn_box_reg: 0.0512 (0.0535)  time: 0.6992  data: 0.0168  max mem: 4551
# Epoch: [19]  [240/752]  eta: 0:06:00  lr: 0.000010  loss: 0.5948 (0.6274)  loss_classifier: 0.1610 (0.1742)  loss_box_reg: 0.3526 (0.3741)  loss_objectness: 0.0268 (0.0259)  loss_rpn_box_reg: 0.0480 (0.0532)  time: 0.6974  data: 0.0165  max mem: 4551
# Epoch: [19]  [250/752]  eta: 0:05:53  lr: 0.000010  loss: 0.6022 (0.6281)  loss_classifier: 0.1610 (0.1746)  loss_box_reg: 0.3651 (0.3743)  loss_objectness: 0.0220 (0.0260)  loss_rpn_box_reg: 0.0457 (0.0533)  time: 0.6925  data: 0.0157  max mem: 4551
# Epoch: [19]  [260/752]  eta: 0:05:45  lr: 0.000010  loss: 0.6364 (0.6289)  loss_classifier: 0.1638 (0.1746)  loss_box_reg: 0.3787 (0.3749)  loss_objectness: 0.0252 (0.0261)  loss_rpn_box_reg: 0.0552 (0.0533)  time: 0.6933  data: 0.0157  max mem: 4551
# Epoch: [19]  [270/752]  eta: 0:05:38  lr: 0.000010  loss: 0.6237 (0.6290)  loss_classifier: 0.1698 (0.1749)  loss_box_reg: 0.3697 (0.3744)  loss_objectness: 0.0272 (0.0260)  loss_rpn_box_reg: 0.0569 (0.0536)  time: 0.6956  data: 0.0158  max mem: 4551
# Epoch: [19]  [280/752]  eta: 0:05:31  lr: 0.000010  loss: 0.5891 (0.6280)  loss_classifier: 0.1630 (0.1746)  loss_box_reg: 0.3468 (0.3737)  loss_objectness: 0.0267 (0.0262)  loss_rpn_box_reg: 0.0503 (0.0535)  time: 0.6947  data: 0.0163  max mem: 4551
# Epoch: [19]  [290/752]  eta: 0:05:24  lr: 0.000010  loss: 0.6343 (0.6286)  loss_classifier: 0.1678 (0.1747)  loss_box_reg: 0.3747 (0.3741)  loss_objectness: 0.0260 (0.0262)  loss_rpn_box_reg: 0.0503 (0.0536)  time: 0.6973  data: 0.0167  max mem: 4551
# Epoch: [19]  [300/752]  eta: 0:05:17  lr: 0.000010  loss: 0.6160 (0.6274)  loss_classifier: 0.1733 (0.1745)  loss_box_reg: 0.3732 (0.3734)  loss_objectness: 0.0248 (0.0260)  loss_rpn_box_reg: 0.0488 (0.0535)  time: 0.6969  data: 0.0162  max mem: 4551
# Epoch: [19]  [310/752]  eta: 0:05:10  lr: 0.000010  loss: 0.6000 (0.6274)  loss_classifier: 0.1733 (0.1748)  loss_box_reg: 0.3477 (0.3733)  loss_objectness: 0.0203 (0.0259)  loss_rpn_box_reg: 0.0471 (0.0534)  time: 0.6915  data: 0.0157  max mem: 4551
# Epoch: [19]  [320/752]  eta: 0:05:03  lr: 0.000010  loss: 0.5895 (0.6264)  loss_classifier: 0.1733 (0.1746)  loss_box_reg: 0.3600 (0.3727)  loss_objectness: 0.0226 (0.0257)  loss_rpn_box_reg: 0.0481 (0.0533)  time: 0.6910  data: 0.0157  max mem: 4551
# Epoch: [19]  [330/752]  eta: 0:04:56  lr: 0.000010  loss: 0.5703 (0.6257)  loss_classifier: 0.1551 (0.1742)  loss_box_reg: 0.3606 (0.3726)  loss_objectness: 0.0192 (0.0256)  loss_rpn_box_reg: 0.0484 (0.0532)  time: 0.6968  data: 0.0164  max mem: 4551
# Epoch: [19]  [340/752]  eta: 0:04:48  lr: 0.000010  loss: 0.6019 (0.6260)  loss_classifier: 0.1675 (0.1742)  loss_box_reg: 0.3690 (0.3730)  loss_objectness: 0.0207 (0.0256)  loss_rpn_box_reg: 0.0510 (0.0532)  time: 0.6992  data: 0.0170  max mem: 4551
# Epoch: [19]  [350/752]  eta: 0:04:41  lr: 0.000010  loss: 0.6305 (0.6259)  loss_classifier: 0.1752 (0.1742)  loss_box_reg: 0.3831 (0.3732)  loss_objectness: 0.0233 (0.0255)  loss_rpn_box_reg: 0.0484 (0.0531)  time: 0.6982  data: 0.0168  max mem: 4551
# Epoch: [19]  [360/752]  eta: 0:04:34  lr: 0.000010  loss: 0.6125 (0.6248)  loss_classifier: 0.1721 (0.1739)  loss_box_reg: 0.3778 (0.3727)  loss_objectness: 0.0216 (0.0253)  loss_rpn_box_reg: 0.0474 (0.0529)  time: 0.6977  data: 0.0163  max mem: 4551
# Epoch: [19]  [370/752]  eta: 0:04:27  lr: 0.000010  loss: 0.5952 (0.6242)  loss_classifier: 0.1671 (0.1737)  loss_box_reg: 0.3585 (0.3725)  loss_objectness: 0.0192 (0.0252)  loss_rpn_box_reg: 0.0474 (0.0528)  time: 0.6945  data: 0.0158  max mem: 4551
# Epoch: [19]  [380/752]  eta: 0:04:20  lr: 0.000010  loss: 0.5952 (0.6231)  loss_classifier: 0.1623 (0.1736)  loss_box_reg: 0.3589 (0.3720)  loss_objectness: 0.0166 (0.0250)  loss_rpn_box_reg: 0.0470 (0.0526)  time: 0.6920  data: 0.0160  max mem: 4551
# Epoch: [19]  [390/752]  eta: 0:04:13  lr: 0.000010  loss: 0.5946 (0.6227)  loss_classifier: 0.1695 (0.1734)  loss_box_reg: 0.3548 (0.3716)  loss_objectness: 0.0186 (0.0252)  loss_rpn_box_reg: 0.0468 (0.0525)  time: 0.6929  data: 0.0161  max mem: 4551
# Epoch: [19]  [400/752]  eta: 0:04:06  lr: 0.000010  loss: 0.6295 (0.6237)  loss_classifier: 0.1794 (0.1735)  loss_box_reg: 0.3863 (0.3721)  loss_objectness: 0.0249 (0.0253)  loss_rpn_box_reg: 0.0501 (0.0528)  time: 0.6974  data: 0.0166  max mem: 4551
# Epoch: [19]  [410/752]  eta: 0:03:59  lr: 0.000010  loss: 0.6324 (0.6233)  loss_classifier: 0.1790 (0.1734)  loss_box_reg: 0.3891 (0.3721)  loss_objectness: 0.0223 (0.0252)  loss_rpn_box_reg: 0.0513 (0.0527)  time: 0.6962  data: 0.0166  max mem: 4551
# Epoch: [19]  [420/752]  eta: 0:03:52  lr: 0.000010  loss: 0.6317 (0.6237)  loss_classifier: 0.1679 (0.1735)  loss_box_reg: 0.3679 (0.3723)  loss_objectness: 0.0223 (0.0252)  loss_rpn_box_reg: 0.0504 (0.0527)  time: 0.6944  data: 0.0161  max mem: 4551
# Epoch: [19]  [430/752]  eta: 0:03:45  lr: 0.000010  loss: 0.6317 (0.6238)  loss_classifier: 0.1809 (0.1737)  loss_box_reg: 0.3679 (0.3725)  loss_objectness: 0.0226 (0.0251)  loss_rpn_box_reg: 0.0491 (0.0526)  time: 0.6973  data: 0.0164  max mem: 4551
# Epoch: [19]  [440/752]  eta: 0:03:38  lr: 0.000010  loss: 0.6463 (0.6251)  loss_classifier: 0.1820 (0.1740)  loss_box_reg: 0.3936 (0.3732)  loss_objectness: 0.0267 (0.0252)  loss_rpn_box_reg: 0.0491 (0.0527)  time: 0.6971  data: 0.0165  max mem: 4551
# Epoch: [19]  [450/752]  eta: 0:03:31  lr: 0.000010  loss: 0.6565 (0.6258)  loss_classifier: 0.1740 (0.1741)  loss_box_reg: 0.3995 (0.3737)  loss_objectness: 0.0289 (0.0254)  loss_rpn_box_reg: 0.0519 (0.0527)  time: 0.6956  data: 0.0164  max mem: 4551
# Epoch: [19]  [460/752]  eta: 0:03:24  lr: 0.000010  loss: 0.6320 (0.6255)  loss_classifier: 0.1706 (0.1739)  loss_box_reg: 0.3814 (0.3735)  loss_objectness: 0.0266 (0.0254)  loss_rpn_box_reg: 0.0522 (0.0527)  time: 0.6968  data: 0.0163  max mem: 4551
# Epoch: [19]  [470/752]  eta: 0:03:17  lr: 0.000010  loss: 0.6141 (0.6252)  loss_classifier: 0.1642 (0.1738)  loss_box_reg: 0.3814 (0.3735)  loss_objectness: 0.0220 (0.0253)  loss_rpn_box_reg: 0.0496 (0.0526)  time: 0.6956  data: 0.0161  max mem: 4551
# Epoch: [19]  [480/752]  eta: 0:03:10  lr: 0.000010  loss: 0.6447 (0.6258)  loss_classifier: 0.1690 (0.1739)  loss_box_reg: 0.3861 (0.3736)  loss_objectness: 0.0242 (0.0254)  loss_rpn_box_reg: 0.0504 (0.0529)  time: 0.6940  data: 0.0158  max mem: 4551
# Epoch: [19]  [490/752]  eta: 0:03:03  lr: 0.000010  loss: 0.6543 (0.6267)  loss_classifier: 0.1831 (0.1741)  loss_box_reg: 0.3825 (0.3739)  loss_objectness: 0.0274 (0.0256)  loss_rpn_box_reg: 0.0562 (0.0532)  time: 0.6955  data: 0.0159  max mem: 4551
# Epoch: [19]  [500/752]  eta: 0:02:56  lr: 0.000010  loss: 0.6210 (0.6263)  loss_classifier: 0.1810 (0.1740)  loss_box_reg: 0.3775 (0.3737)  loss_objectness: 0.0214 (0.0255)  loss_rpn_box_reg: 0.0524 (0.0531)  time: 0.6965  data: 0.0161  max mem: 4551
# Epoch: [19]  [510/752]  eta: 0:02:49  lr: 0.000010  loss: 0.6092 (0.6265)  loss_classifier: 0.1695 (0.1740)  loss_box_reg: 0.3699 (0.3738)  loss_objectness: 0.0238 (0.0256)  loss_rpn_box_reg: 0.0519 (0.0532)  time: 0.6980  data: 0.0167  max mem: 4551
# Epoch: [19]  [520/752]  eta: 0:02:42  lr: 0.000010  loss: 0.6268 (0.6265)  loss_classifier: 0.1695 (0.1740)  loss_box_reg: 0.3662 (0.3736)  loss_objectness: 0.0275 (0.0257)  loss_rpn_box_reg: 0.0558 (0.0532)  time: 0.6984  data: 0.0168  max mem: 4551
# Epoch: [19]  [530/752]  eta: 0:02:35  lr: 0.000010  loss: 0.6404 (0.6272)  loss_classifier: 0.1701 (0.1742)  loss_box_reg: 0.3618 (0.3738)  loss_objectness: 0.0249 (0.0258)  loss_rpn_box_reg: 0.0563 (0.0534)  time: 0.6990  data: 0.0165  max mem: 4551
# Epoch: [19]  [540/752]  eta: 0:02:28  lr: 0.000010  loss: 0.6404 (0.6281)  loss_classifier: 0.1701 (0.1744)  loss_box_reg: 0.3886 (0.3743)  loss_objectness: 0.0283 (0.0260)  loss_rpn_box_reg: 0.0563 (0.0534)  time: 0.6970  data: 0.0167  max mem: 4551
# Epoch: [19]  [550/752]  eta: 0:02:21  lr: 0.000010  loss: 0.6246 (0.6279)  loss_classifier: 0.1674 (0.1744)  loss_box_reg: 0.3568 (0.3740)  loss_objectness: 0.0257 (0.0259)  loss_rpn_box_reg: 0.0503 (0.0535)  time: 0.6944  data: 0.0166  max mem: 4551
# Epoch: [19]  [560/752]  eta: 0:02:14  lr: 0.000010  loss: 0.5954 (0.6277)  loss_classifier: 0.1644 (0.1744)  loss_box_reg: 0.3539 (0.3739)  loss_objectness: 0.0194 (0.0260)  loss_rpn_box_reg: 0.0474 (0.0534)  time: 0.6944  data: 0.0161  max mem: 4551
# Epoch: [19]  [570/752]  eta: 0:02:07  lr: 0.000010  loss: 0.6048 (0.6274)  loss_classifier: 0.1688 (0.1744)  loss_box_reg: 0.3519 (0.3737)  loss_objectness: 0.0195 (0.0259)  loss_rpn_box_reg: 0.0472 (0.0533)  time: 0.6933  data: 0.0160  max mem: 4551
# Epoch: [19]  [580/752]  eta: 0:02:00  lr: 0.000010  loss: 0.6306 (0.6280)  loss_classifier: 0.1827 (0.1745)  loss_box_reg: 0.3800 (0.3740)  loss_objectness: 0.0233 (0.0260)  loss_rpn_box_reg: 0.0482 (0.0535)  time: 0.6929  data: 0.0161  max mem: 4551
# Epoch: [19]  [590/752]  eta: 0:01:53  lr: 0.000010  loss: 0.6585 (0.6283)  loss_classifier: 0.1746 (0.1746)  loss_box_reg: 0.3916 (0.3742)  loss_objectness: 0.0265 (0.0261)  loss_rpn_box_reg: 0.0482 (0.0535)  time: 0.6949  data: 0.0160  max mem: 4551
# Epoch: [19]  [600/752]  eta: 0:01:46  lr: 0.000010  loss: 0.6294 (0.6285)  loss_classifier: 0.1821 (0.1748)  loss_box_reg: 0.3715 (0.3742)  loss_objectness: 0.0262 (0.0261)  loss_rpn_box_reg: 0.0524 (0.0535)  time: 0.6983  data: 0.0160  max mem: 4551
# Epoch: [19]  [610/752]  eta: 0:01:39  lr: 0.000010  loss: 0.6294 (0.6286)  loss_classifier: 0.1864 (0.1748)  loss_box_reg: 0.3727 (0.3742)  loss_objectness: 0.0228 (0.0261)  loss_rpn_box_reg: 0.0522 (0.0534)  time: 0.6962  data: 0.0159  max mem: 4551
# Epoch: [19]  [620/752]  eta: 0:01:32  lr: 0.000010  loss: 0.6655 (0.6296)  loss_classifier: 0.1888 (0.1752)  loss_box_reg: 0.3837 (0.3747)  loss_objectness: 0.0227 (0.0261)  loss_rpn_box_reg: 0.0512 (0.0535)  time: 0.6938  data: 0.0163  max mem: 4551
# Epoch: [19]  [630/752]  eta: 0:01:25  lr: 0.000010  loss: 0.6492 (0.6294)  loss_classifier: 0.1794 (0.1751)  loss_box_reg: 0.3780 (0.3747)  loss_objectness: 0.0234 (0.0260)  loss_rpn_box_reg: 0.0512 (0.0535)  time: 0.6989  data: 0.0175  max mem: 4551
# Epoch: [19]  [640/752]  eta: 0:01:18  lr: 0.000010  loss: 0.6121 (0.6293)  loss_classifier: 0.1638 (0.1750)  loss_box_reg: 0.3732 (0.3747)  loss_objectness: 0.0237 (0.0260)  loss_rpn_box_reg: 0.0480 (0.0536)  time: 0.6986  data: 0.0173  max mem: 4551
# Epoch: [19]  [650/752]  eta: 0:01:11  lr: 0.000010  loss: 0.6197 (0.6293)  loss_classifier: 0.1740 (0.1751)  loss_box_reg: 0.3817 (0.3748)  loss_objectness: 0.0226 (0.0260)  loss_rpn_box_reg: 0.0480 (0.0534)  time: 0.6949  data: 0.0164  max mem: 4551
# Epoch: [19]  [660/752]  eta: 0:01:04  lr: 0.000010  loss: 0.6101 (0.6290)  loss_classifier: 0.1730 (0.1751)  loss_box_reg: 0.3713 (0.3745)  loss_objectness: 0.0239 (0.0259)  loss_rpn_box_reg: 0.0492 (0.0534)  time: 0.6957  data: 0.0160  max mem: 4551
# Epoch: [19]  [670/752]  eta: 0:00:57  lr: 0.000010  loss: 0.5835 (0.6287)  loss_classifier: 0.1645 (0.1749)  loss_box_reg: 0.3657 (0.3744)  loss_objectness: 0.0264 (0.0260)  loss_rpn_box_reg: 0.0492 (0.0534)  time: 0.6952  data: 0.0159  max mem: 4551
# Epoch: [19]  [680/752]  eta: 0:00:50  lr: 0.000010  loss: 0.6341 (0.6287)  loss_classifier: 0.1752 (0.1750)  loss_box_reg: 0.3671 (0.3744)  loss_objectness: 0.0293 (0.0260)  loss_rpn_box_reg: 0.0524 (0.0534)  time: 0.6964  data: 0.0169  max mem: 4551
# Epoch: [19]  [690/752]  eta: 0:00:43  lr: 0.000010  loss: 0.6589 (0.6296)  loss_classifier: 0.1856 (0.1752)  loss_box_reg: 0.3897 (0.3747)  loss_objectness: 0.0271 (0.0261)  loss_rpn_box_reg: 0.0604 (0.0536)  time: 0.6972  data: 0.0168  max mem: 4551
# Epoch: [19]  [700/752]  eta: 0:00:36  lr: 0.000010  loss: 0.6557 (0.6295)  loss_classifier: 0.1870 (0.1753)  loss_box_reg: 0.3887 (0.3747)  loss_objectness: 0.0259 (0.0260)  loss_rpn_box_reg: 0.0565 (0.0535)  time: 0.6956  data: 0.0160  max mem: 4551
# Epoch: [19]  [710/752]  eta: 0:00:29  lr: 0.000010  loss: 0.6383 (0.6301)  loss_classifier: 0.1830 (0.1756)  loss_box_reg: 0.3740 (0.3748)  loss_objectness: 0.0199 (0.0260)  loss_rpn_box_reg: 0.0523 (0.0537)  time: 0.6942  data: 0.0161  max mem: 4551
# Epoch: [19]  [720/752]  eta: 0:00:22  lr: 0.000010  loss: 0.6391 (0.6301)  loss_classifier: 0.1796 (0.1756)  loss_box_reg: 0.3735 (0.3748)  loss_objectness: 0.0199 (0.0259)  loss_rpn_box_reg: 0.0552 (0.0537)  time: 0.6957  data: 0.0163  max mem: 4551
# Epoch: [19]  [730/752]  eta: 0:00:15  lr: 0.000010  loss: 0.6391 (0.6308)  loss_classifier: 0.1799 (0.1758)  loss_box_reg: 0.3796 (0.3752)  loss_objectness: 0.0228 (0.0260)  loss_rpn_box_reg: 0.0557 (0.0538)  time: 0.6972  data: 0.0165  max mem: 4551
# Epoch: [19]  [740/752]  eta: 0:00:08  lr: 0.000010  loss: 0.6364 (0.6312)  loss_classifier: 0.1816 (0.1760)  loss_box_reg: 0.3750 (0.3753)  loss_objectness: 0.0246 (0.0260)  loss_rpn_box_reg: 0.0534 (0.0538)  time: 0.6978  data: 0.0168  max mem: 4551
# Epoch: [19]  [750/752]  eta: 0:00:01  lr: 0.000010  loss: 0.6305 (0.6312)  loss_classifier: 0.1816 (0.1760)  loss_box_reg: 0.3684 (0.3753)  loss_objectness: 0.0223 (0.0261)  loss_rpn_box_reg: 0.0525 (0.0539)  time: 0.6930  data: 0.0164  max mem: 4551
# Epoch: [19]  [751/752]  eta: 0:00:00  lr: 0.000010  loss: 0.6305 (0.6312)  loss_classifier: 0.1816 (0.1759)  loss_box_reg: 0.3716 (0.3753)  loss_objectness: 0.0223 (0.0261)  loss_rpn_box_reg: 0.0535 (0.0539)  time: 0.6693  data: 0.0160  max mem: 4551
# Epoch: [19] Total time: 0:08:44 (0.6980 s / it)
# creating index...
# index created!
# Test:  [ 0/92]  eta: 0:02:16  model_time: 0.3448 (0.3448)  evaluator_time: 0.1743 (0.1743)  time: 1.4826  data: 0.9142  max mem: 4551
# Test:  [91/92]  eta: 0:00:00  model_time: 0.2708 (0.2721)  evaluator_time: 0.2680 (0.2640)  time: 0.5572  data: 0.0155  max mem: 4551
# Test: Total time: 0:00:53 (0.5796 s / it)
# Averaged stats: model_time: 0.2708 (0.2721)  evaluator_time: 0.2680 (0.2640)
# Accumulating evaluation results...
# DONE (t=0.20s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.515
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.924
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.519
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.093
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.508
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.552
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.157
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.574
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.606
